# %% [markdown]
# SLaM (Source, Light and Mass): Mass Total + Subhalo NFW + Source Parametric
# ===========================================================================
#
# SLaM pipelines break the analysis down into multiple pipelines which focus on modeling a specific aspect of the strong
# lens, first the Source, then the (lens) Light and finally the Mass. Each of these pipelines has it own inputs which
# which customize the model and analysis in that pipeline.
#
# The models fitted in earlier pipelines determine the model used in later pipelines. For example, if the SOURCE PIPELINE
# uses a parametric `EllSersic` profile for the bulge, this will be used in the subsequent MASS TOTAL PIPELINE.
#
# Using a SOURCE PARAMETRIC PIPELINE, MASS TOTAL PIPELINE and SUBHALO PIPELINE this SLaM script fits `Interferometer` of a strong lens
# system, where in the final model:
#
#  - The lens galaxy's light is omitted from the data and model.
#  - The lens galaxy's total mass distribution is an `EllIsothermal`.
#  - A dark matter subhalo near The lens galaxy mass is included as a`SphNFWMCRLudLow`.
#  - The source galaxy is an `EllSersic`.
#
# This uses the SLaM pipelines:
#
#  `source_parametric/no_lens_light`
#  `mass_total/no_lens_light`
#  `subhalo/detection_single_plane`
#
# Check them out for a full description of the analysis!

# %%
# %matplotlib inline
from pyprojroot import here
workspace_path = str(here())
# %cd $workspace_path
print(f"Working Directory has been set to `{workspace_path}`")

import os
import sys
from os import path
import autofit as af
import autolens as al
import autolens.plot as aplt

sys.path.insert(0, os.getcwd())
import slam
# Out:
# /mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace
# Working Directory has been set to `/mnt/c/Users/Jammy/Code/PyAuto/autolens_workspace`

# %% [markdown]
# __Dataset + Masking__
#
# Load the `Interferometer` data, define the visibility and real-space masks and plot them.

# %%
real_space_mask = al.Mask2D.circular(
    shape_native=(151, 151), pixel_scales=0.05, radius=3.0
)

dataset_name = "mass_sie__subhalo_nfw__source_sersic"
dataset_path = path.join("dataset", "interferometer", dataset_name)

interferometer = al.Interferometer.from_fits(
    visibilities_path=path.join(dataset_path, "visibilities.fits"),
    noise_map_path=path.join(dataset_path, "noise_map.fits"),
    uv_wavelengths_path=path.join(dataset_path, "uv_wavelengths.fits"),
    real_space_mask=real_space_mask,
)
interferometer = interferometer.apply_settings(
    settings=al.SettingsInterferometer(transformer_class=al.TransformerNUFFT)
)

interferometer_plotter = aplt.InterferometerPlotter(interferometer=interferometer)
interferometer_plotter.subplot_interferometer()
interferometer_plotter.subplot_dirty_images()
# Out:
# /mnt/c/Users/Jammy/Code/PyAuto/PyAutoArray/autoarray/plot/mat_wrap/mat_plot.py:178: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(rows, columns, self.subplot_index)
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/pynufft/linalg/nufft_cpu.py:381: ComplexWarning: Casting complex values to real discards the imaginary part
#   xx.ravel()[self.NdCPUorder * self.batch + bat] = k.ravel()[
# /home/jammy/venvs/PyAuto/lib/python3.8/site-packages/pynufft/linalg/nufft_cpu.py:381: ComplexWarning: Casting complex values to real discards the imaginary part
#   xx.ravel()[self.NdCPUorder * self.batch + bat] = k.ravel()[

# %% [markdown]
# __Paths__
#
# The path the results of all chained searches are output:

# %%
path_prefix = path.join("interferometer", "slam")

# %% [markdown]
# __Redshifts__
#
# The redshifts of the lens and source galaxies, which are used to perform unit converions of the model and data (e.g.
# from arc-seconds to kiloparsecs, masses to solar masses, etc.).

# %%
redshift_lens = 0.5
redshift_source = 1.0

# %% [markdown]
# __HYPER SETUP__
#
# The `SetupHyper` determines which hyper-mode features are used during the model-fit.

# %%
setup_hyper = al.SetupHyper(
    hyper_galaxies_lens=False,
    hyper_galaxies_source=False,
    hyper_image_sky=None,
    hyper_background_noise=None,
)

# %% [markdown]
# __SOURCE PARAMETRIC PIPELINE (no lens light)__
#
# The SOURCE PARAMETRIC PIPELINE (no lens light) uses one search to initialize a robust model for the source galaxy's
# light, which in this example:
#
#  - Uses a parametric `EllSersic` bulge for the source's light (omitting a disk / envelope).
#  - Uses an `EllIsothermal` model for the lens's total mass distribution with an `ExternalShear`.
#
#  __Settings__:
#
#  - Mass Centre: Fix the mass profile centre to (0.0, 0.0) (this assumption will be relaxed in the MASS TOTAL PIPELINE).

# %%
analysis = al.AnalysisInterferometer(dataset=interferometer)

source_parametric_results = slam.source_parametric.no_lens_light(
    path_prefix=path_prefix,
    unique_tag=dataset_name,
    analysis=analysis,
    setup_hyper=setup_hyper,
    mass=af.Model(al.mp.EllIsothermal),
    shear=af.Model(al.mp.ExternalShear),
    source_bulge=af.Model(al.lp.EllSersic),
    mass_centre=(0.0, 0.0),
    redshift_lens=0.5,
    redshift_source=1.0,
)
# Out:
# 2021-05-10 15:38:33,549 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 56.96it/s, +200 | bound: 0 | nc: 1 | ncall: 202 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.209]
# 2021-05-10 15:38:33,620 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:33,821 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:33,992 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# __MASS TOTAL PIPELINE (no lens light)__
#
# The MASS TOTAL PIPELINE (no lens light) uses one search to fits a complex lens mass model to a high level of accuracy,
# using the lens mass model and source model of the SOURCE PIPELINE to initialize the model priors. In this example it:
#
#  - Uses an `EllPowerLaw` model for the lens's total mass distribution [The centre if unfixed from (0.0, 0.0)].
#  - Uses the `EllSersic` model representing a bulge for the source's light.
#  - Carries the lens redshift, source redshift and `ExternalShear` of the SOURCE PIPELINE through to the MASS TOTAL PIPELINE.

# %%
analysis = al.AnalysisInterferometer(dataset=interferometer)

mass_results = slam.mass_total.no_lens_light(
    path_prefix=path_prefix,
    unique_tag=dataset_name,
    analysis=analysis,
    setup_hyper=setup_hyper,
    source_results=source_parametric_results,
    mass=af.Model(al.mp.EllPowerLaw),
)
# Out:
# 2021-05-10 15:38:34,763 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 45.74it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-10 15:38:34,826 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:35,020 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:35,192 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# __SUBHALO PIPELINE (single plane detection)__
#
# The SUBHALO PIPELINE (single plane detection) consists of the following searches:
#
#  1) Refit the lens and source model, to refine the model evidence for comparing to the models fitted which include a
#  subhalo. This uses the same model as fitted in the MASS TOTAL PIPELINE.
#  2) Performs a grid-search of non-linear searches to attempt to detect a dark matter subhalo.
#  3) If there is a successful detection a final search is performed to refine its parameters.
#
# For this runner the SUBHALO PIPELINE customizes:
#
#  - The [number_of_steps x number_of_steps] size of the grid-search, as well as the dimensions it spans in arc-seconds.
#  - The `number_of_cores` used for the gridsearch, where `number_of_cores > 1` performs the model-fits in paralle using
#  the Python multiprocessing module.

# %%
analysis = al.AnalysisInterferometer(dataset=interferometer)

subhalo_results = slam.subhalo.detection_single_plane(
    path_prefix=path_prefix,
    unique_tag=dataset_name,
    analysis=analysis,
    setup_hyper=setup_hyper,
    mass_results=mass_results,
    subhalo_mass=af.Model(al.mp.SphNFWMCRLudlow),
    grid_dimension_arcsec=3.0,
    number_of_steps=5,
)
# Out:
# 2021-05-10 15:38:36,059 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 43.02it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-10 15:38:36,125 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:36,315 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:36,485 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:37,111 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00,  3.50it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:37,700 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:37,950 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:38,186 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:38,687 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.61it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:38,752 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:39,000 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:39,235 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:39,730 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.04it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:39,792 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:40,038 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:40,274 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:40,768 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.69it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:40,832 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:41,076 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:41,311 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:41,801 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.03it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:41,868 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:42,112 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:42,349 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:42,843 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.49it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:42,910 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:43,157 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:43,394 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:43,892 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 41.08it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:43,954 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:44,200 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:44,449 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:44,952 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.36it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:45,018 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:45,270 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:45,505 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:46,002 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.24it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:46,067 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:46,313 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:46,546 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:47,046 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 35.49it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:47,117 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:47,369 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:47,607 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:48,104 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.98it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:48,169 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:48,415 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:48,648 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:49,145 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.94it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:49,210 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:49,458 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:49,689 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:50,187 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.69it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:50,252 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:50,497 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:50,728 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:51,228 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.72it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:51,291 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:51,543 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:51,776 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:52,268 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.87it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:52,333 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:52,579 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:52,820 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:53,336 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.69it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:53,401 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:53,649 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:53,885 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:54,391 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.69it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:54,454 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:54,696 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:54,925 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:55,427 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 36.66it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:55,496 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:55,735 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:55,975 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:56,471 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.98it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:56,537 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:56,785 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:57,024 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:57,530 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 37.67it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:57,596 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:57,849 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:58,087 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:58,587 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 39.26it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:58,652 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:58,901 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:59,141 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:59,645 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.00it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:38:59,709 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:38:59,960 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:00,191 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:00,691 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.33it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:39:00,754 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:01,002 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:01,237 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:01,740 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 37.87it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:39:01,806 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:02,057 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:02,293 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:02,804 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 40.80it/s, +50 | bound: 0 | nc: 1 | ncall: 52 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# 2021-05-10 15:39:02,867 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:03,113 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:03,349 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:04,248 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# 2it [00:00, 38.68it/s, +100 | bound: 0 | nc: 1 | ncall: 102 | eff(%): 100.000 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.109]
# 2021-05-10 15:39:04,320 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:04,601 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-05-10 15:39:04,861 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# Finish.
